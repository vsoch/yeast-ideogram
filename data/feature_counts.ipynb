# %%
import json
import pandas

with open("features-count.json","r") as fd:
    counts = json.loads(fd.read())
counts
# Out:
# {'ORF': 6604,
#  'CDS': 7074,
#  'ARS': 352,
#  'telomere': 32,
#  'telomeric_repeat': 31,
#  'X_element': 32,
#  'X_element_combinatorial_repeat': 28,
#  'long_terminal_repeat': 383,
#  'ARS_consensus_sequence': 196,
#  'intron': 377,
#  'ncRNA_gene': 18,
#  'noncoding_exon': 484,
#  'tRNA_gene': 299,
#  'snoRNA_gene': 77,
#  'centromere': 16,
#  'centromere_DNA_Element_I': 16,
#  'centromere_DNA_Element_II': 16,
#  'centromere_DNA_Element_III': 16,
#  'transposable_element_gene': 91,
#  'LTR_retrotransposon': 50,
#  'pseudogene': 12,
#  'Y_prime_element': 19,
#  'five_prime_UTR_intron': 24,
#  'plus_1_translational_frameshift': 47,
#  'matrix_attachment_site': 8,
#  'gene_group': 3,
#  'snRNA_gene': 6,
#  'rRNA_gene': 27,
#  'external_transcribed_spacer_region': 8,
#  'internal_transcribed_spacer_region': 8,
#  'non_transcribed_region': 3,
#  'blocked_reading_frame': 6,
#  'origin_of_replication': 8,
#  'telomerase_RNA_gene': 1,
#  'silent_mating_type_cassette_array': 2,
# ...

# %%
df = pandas.DataFrame(counts.values())
df.index = list(counts.keys())
df
# Out:
#                                         0
# ORF                                  6604
# CDS                                  7074
# ARS                                   352
# telomere                               32
# telomeric_repeat                       31
# X_element                              32
# X_element_combinatorial_repeat         28
# long_terminal_repeat                  383
# ARS_consensus_sequence                196
# intron                                377
# ncRNA_gene                             18
# noncoding_exon                        484
# tRNA_gene                             299
# snoRNA_gene                            77
# centromere                             16
# centromere_DNA_Element_I               16
# centromere_DNA_Element_II              16
# centromere_DNA_Element_III             16
# transposable_element_gene              91
# LTR_retrotransposon                    50
# pseudogene                             12
# ...

# %%
df.plot(kind='barh', figsize=(12,12))
# Out:
# <AxesSubplot:>
